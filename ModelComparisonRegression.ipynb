# %% [markdown]
# # Model Comparison and Feature Selection
#
# This notebook provides supervised learning tools to understand associations between the target variable and the predictors. The supporting Python code is in ModelTools.py. Many of the functions have additional arguments that are defaulted. For more details look through the code. Also add any functions you find useful.
#
# # Outline
#
# <!-- MarkdownTOC autolink=true autoanchor=true bracket=round -->
#
# - [Part One - Univariate Analysis](#part-one---univariate-analysis)
#     - [Load Data and Specify Variables](#load-data-and-specify-variables)
#     - [One Hot Encode Categorical Variables](#one-hot-encode-categorical-variables)
#     - [Linear Univariate Analysis](#linear-univariate-analysis)
#     - [Random Forest Univariate Analysis](#random-forest-univariate-analysis)
#     - [Gradient Boosting Univariate Analysis](#gradient-boosting-univariate-analysis)
# - [Part Two - Model Comparison](#part-two---model-comparison)
# - [Part Three - Variable Selection](#part-three---variable-selection)
#     - [Random Forest](#random-forest)
#     - [Gradient Boosting](#gradient-boosting)
#
# <!-- MarkdownTOC -->

# %% [markdown]
# <a name="part-one---univariate-analysis"></a>
# # Part One - Univariate Analysis

# %% [markdown]
# <a name="load-data-and-specify-variables"></a>
# ## Load Data and Specify Variables
#
# In this section we will load our dataset, print the index of each feature and then specify which variables are predictors, target, controls (optional), and weight (optional). For variables with null values, null_value_cleanup will create IS_NULL indicator variables. If you prefer another method of dealing with missing values, like imputing values (e.g. mean, median, mode), write a function to do it, put it in EDATools, and call it below.

# %%
import EDATools
import ModelTools
import pandas as pd
import numpy as np
import warnings
#import pyodbc as odbc

#cnxn = odbc.connect('DRIVER={SQL SERVER}; SERVER=server name here; Database=database name here; trusted_connection=yes')
#dataset = pd.io.sql.read_sql_query(""" Query here """, cnxn)

dataset = pd.read_csv("C:/Users/dsmit/ModelTools/HousePrice_Regression/train.csv") 
dataset.rename(columns={'1stFlrSF': 'FirstFlrSF', '2ndFlrSF': 'SecondFlrSF', '3SsnPorch': 'ThreeSsnPorch'}, inplace=True)

EDATools.null_value_cleanup(dataset)

# Print the index of each feature.
for i, col in enumerate(dataset.columns):
    print(i, col)
# Out:
# 0 Id
# 1 MSSubClass
# 2 MSZoning
# 3 LotFrontage
# 4 LotFrontage_ISNULL
# 5 LotArea
# 6 Street
# 7 Alley
# 8 LotShape
# 9 LandContour
# 10 Utilities
# 11 LotConfig
# 12 LandSlope
# 13 Neighborhood
# 14 Condition1
# 15 Condition2
# 16 BldgType
# 17 HouseStyle
# 18 OverallQual
# 19 OverallCond
# 20 YearBuilt
# 21 YearRemodAdd
# 22 RoofStyle
# 23 RoofMatl
# 24 Exterior1st
# 25 Exterior2nd
# 26 MasVnrType
# 27 MasVnrArea
# 28 MasVnrArea_ISNULL
# 29 ExterQual
# 30 ExterCond
# 31 Foundation
# 32 BsmtQual
# 33 BsmtCond
# 34 BsmtExposure
# 35 BsmtFinType1
# 36 BsmtFinSF1
# 37 BsmtFinType2
# 38 BsmtFinSF2
# 39 BsmtUnfSF
# 40 TotalBsmtSF
# 41 Heating
# 42 HeatingQC
# 43 CentralAir
# 44 Electrical
# 45 FirstFlrSF
# 46 SecondFlrSF
# 47 LowQualFinSF
# 48 GrLivArea
# 49 BsmtFullBath
# 50 BsmtHalfBath
# 51 FullBath
# 52 HalfBath
# 53 BedroomAbvGr
# 54 KitchenAbvGr
# 55 KitchenQual
# 56 TotRmsAbvGrd
# 57 Functional
# 58 Fireplaces
# 59 FireplaceQu
# 60 GarageType
# 61 GarageYrBlt
# 62 GarageYrBlt_ISNULL
# 63 GarageFinish
# 64 GarageCars
# 65 GarageArea
# 66 GarageQual
# 67 GarageCond
# 68 PavedDrive
# 69 WoodDeckSF
# 70 OpenPorchSF
# 71 EnclosedPorch
# 72 ThreeSsnPorch
# 73 ScreenPorch
# 74 PoolArea
# 75 PoolQC
# 76 Fence
# 77 MiscFeature
# 78 MiscVal
# 79 MoSold
# 80 YrSold
# 81 SaleType
# 82 SaleCondition
# 83 SalePrice

# %% [markdown]
# Set index of predictors, target, controls, weight.

# %%
predictors = np.arange(1,83)
numeric_cat_index = np.array([1,4,18,19,28,62,79])
target = 83

# %% [markdown]
# <a name="one-hot-encode-categorical-variables"></a>
# ## One Hot Encode Categorical Variables
#
# For the purpose of modeling we will one-hot encode each categorical variable. We will also re-name our features so that categorical variables follow the convention VariableName-LevelName. This will allow us to keep track of variable level characteristics, in particular variable importance.

# %%
dataset_enc = ModelTools.CreateDummyVars(dataset,predictors,target,numeric_cat_index)

# %%
for i, col in enumerate(dataset_enc.columns):
    print(i, col)
# Out:
# 0 MSSubClass-20
# 1 MSSubClass-30
# 2 MSSubClass-40
# 3 MSSubClass-45
# 4 MSSubClass-50
# 5 MSSubClass-60
# 6 MSSubClass-70
# 7 MSSubClass-75
# 8 MSSubClass-80
# 9 MSSubClass-85
# 10 MSSubClass-90
# 11 MSSubClass-120
# 12 MSSubClass-160
# 13 MSSubClass-180
# 14 MSSubClass-190
# 15 MSZoning-C (all)
# 16 MSZoning-FV
# 17 MSZoning-RH
# 18 MSZoning-RL
# 19 MSZoning-RM
# 20 LotFrontage_ISNULL-0
# 21 LotFrontage_ISNULL-1
# 22 Street-Grvl
# 23 Street-Pave
# 24 Alley-Grvl
# 25 Alley-Null_Value
# 26 Alley-Pave
# 27 LotShape-IR1
# 28 LotShape-IR2
# 29 LotShape-IR3
# 30 LotShape-Reg
# 31 LandContour-Bnk
# 32 LandContour-HLS
# 33 LandContour-Low
# 34 LandContour-Lvl
# 35 Utilities-AllPub
# 36 Utilities-NoSeWa
# 37 LotConfig-Corner
# 38 LotConfig-CulDSac
# 39 LotConfig-FR2
# 40 LotConfig-FR3
# 41 LotConfig-Inside
# 42 LandSlope-Gtl
# 43 LandSlope-Mod
# 44 LandSlope-Sev
# 45 Neighborhood-Blmngtn
# 46 Neighborhood-Blueste
# 47 Neighborhood-BrDale
# 48 Neighborhood-BrkSide
# 49 Neighborhood-ClearCr
# 50 Neighborhood-CollgCr
# 51 Neighborhood-Crawfor
# 52 Neighborhood-Edwards
# 53 Neighborhood-Gilbert
# 54 Neighborhood-IDOTRR
# 55 Neighborhood-MeadowV
# 56 Neighborhood-Mitchel
# 57 Neighborhood-NAmes
# 58 Neighborhood-NPkVill
# 59 Neighborhood-NWAmes
# 60 Neighborhood-NoRidge
# 61 Neighborhood-NridgHt
# 62 Neighborhood-OldTown
# 63 Neighborhood-SWISU
# 64 Neighborhood-Sawyer
# 65 Neighborhood-SawyerW
# 66 Neighborhood-Somerst
# 67 Neighborhood-StoneBr
# 68 Neighborhood-Timber
# 69 Neighborhood-Veenker
# 70 Condition1-Artery
# 71 Condition1-Feedr
# 72 Condition1-Norm
# 73 Condition1-PosA
# 74 Condition1-PosN
# 75 Condition1-RRAe
# 76 Condition1-RRAn
# 77 Condition1-RRNe
# 78 Condition1-RRNn
# 79 Condition2-Artery
# 80 Condition2-Feedr
# 81 Condition2-Norm
# 82 Condition2-PosA
# 83 Condition2-PosN
# 84 Condition2-RRAe
# 85 Condition2-RRAn
# 86 Condition2-RRNn
# 87 BldgType-1Fam
# 88 BldgType-2fmCon
# 89 BldgType-Duplex
# 90 BldgType-Twnhs
# 91 BldgType-TwnhsE
# 92 HouseStyle-1.5Fin
# 93 HouseStyle-1.5Unf
# 94 HouseStyle-1Story
# 95 HouseStyle-2.5Fin
# 96 HouseStyle-2.5Unf
# 97 HouseStyle-2Story
# 98 HouseStyle-SFoyer
# 99 HouseStyle-SLvl
# 100 OverallQual-1
# 101 OverallQual-2
# 102 OverallQual-3
# 103 OverallQual-4
# 104 OverallQual-5
# 105 OverallQual-6
# 106 OverallQual-7
# 107 OverallQual-8
# 108 OverallQual-9
# 109 OverallQual-10
# 110 OverallCond-1
# 111 OverallCond-2
# 112 OverallCond-3
# 113 OverallCond-4
# 114 OverallCond-5
# 115 OverallCond-6
# 116 OverallCond-7
# 117 OverallCond-8
# 118 OverallCond-9
# 119 RoofStyle-Flat
# 120 RoofStyle-Gable
# 121 RoofStyle-Gambrel
# 122 RoofStyle-Hip
# 123 RoofStyle-Mansard
# 124 RoofStyle-Shed
# 125 RoofMatl-ClyTile
# 126 RoofMatl-CompShg
# 127 RoofMatl-Membran
# 128 RoofMatl-Metal
# 129 RoofMatl-Roll
# 130 RoofMatl-Tar&Grv
# 131 RoofMatl-WdShake
# 132 RoofMatl-WdShngl
# 133 Exterior1st-AsbShng
# 134 Exterior1st-AsphShn
# 135 Exterior1st-BrkComm
# 136 Exterior1st-BrkFace
# 137 Exterior1st-CBlock
# 138 Exterior1st-CemntBd
# 139 Exterior1st-HdBoard
# 140 Exterior1st-ImStucc
# 141 Exterior1st-MetalSd
# 142 Exterior1st-Plywood
# 143 Exterior1st-Stone
# 144 Exterior1st-Stucco
# 145 Exterior1st-VinylSd
# 146 Exterior1st-Wd Sdng
# 147 Exterior1st-WdShing
# 148 Exterior2nd-AsbShng
# 149 Exterior2nd-AsphShn
# 150 Exterior2nd-Brk Cmn
# 151 Exterior2nd-BrkFace
# 152 Exterior2nd-CBlock
# 153 Exterior2nd-CmentBd
# 154 Exterior2nd-HdBoard
# 155 Exterior2nd-ImStucc
# 156 Exterior2nd-MetalSd
# 157 Exterior2nd-Other
# 158 Exterior2nd-Plywood
# 159 Exterior2nd-Stone
# 160 Exterior2nd-Stucco
# 161 Exterior2nd-VinylSd
# 162 Exterior2nd-Wd Sdng
# 163 Exterior2nd-Wd Shng
# 164 MasVnrType-BrkCmn
# 165 MasVnrType-BrkFace
# 166 MasVnrType-None
# 167 MasVnrType-Null_Value
# 168 MasVnrType-Stone
# 169 MasVnrArea_ISNULL-0
# 170 MasVnrArea_ISNULL-1
# 171 ExterQual-Ex
# 172 ExterQual-Fa
# 173 ExterQual-Gd
# 174 ExterQual-TA
# 175 ExterCond-Ex
# 176 ExterCond-Fa
# 177 ExterCond-Gd
# 178 ExterCond-Po
# 179 ExterCond-TA
# 180 Foundation-BrkTil
# 181 Foundation-CBlock
# 182 Foundation-PConc
# 183 Foundation-Slab
# 184 Foundation-Stone
# 185 Foundation-Wood
# 186 BsmtQual-Ex
# 187 BsmtQual-Fa
# 188 BsmtQual-Gd
# 189 BsmtQual-Null_Value
# 190 BsmtQual-TA
# 191 BsmtCond-Fa
# 192 BsmtCond-Gd
# 193 BsmtCond-Null_Value
# 194 BsmtCond-Po
# 195 BsmtCond-TA
# 196 BsmtExposure-Av
# 197 BsmtExposure-Gd
# 198 BsmtExposure-Mn
# 199 BsmtExposure-No
# 200 BsmtExposure-Null_Value
# 201 BsmtFinType1-ALQ
# 202 BsmtFinType1-BLQ
# 203 BsmtFinType1-GLQ
# 204 BsmtFinType1-LwQ
# 205 BsmtFinType1-Null_Value
# 206 BsmtFinType1-Rec
# 207 BsmtFinType1-Unf
# 208 BsmtFinType2-ALQ
# 209 BsmtFinType2-BLQ
# 210 BsmtFinType2-GLQ
# 211 BsmtFinType2-LwQ
# 212 BsmtFinType2-Null_Value
# 213 BsmtFinType2-Rec
# 214 BsmtFinType2-Unf
# 215 Heating-Floor
# 216 Heating-GasA
# 217 Heating-GasW
# 218 Heating-Grav
# 219 Heating-OthW
# 220 Heating-Wall
# 221 HeatingQC-Ex
# 222 HeatingQC-Fa
# 223 HeatingQC-Gd
# 224 HeatingQC-Po
# 225 HeatingQC-TA
# 226 CentralAir-N
# 227 CentralAir-Y
# 228 Electrical-FuseA
# 229 Electrical-FuseF
# 230 Electrical-FuseP
# 231 Electrical-Mix
# 232 Electrical-Null_Value
# 233 Electrical-SBrkr
# 234 KitchenQual-Ex
# 235 KitchenQual-Fa
# 236 KitchenQual-Gd
# 237 KitchenQual-TA
# 238 Functional-Maj1
# 239 Functional-Maj2
# 240 Functional-Min1
# 241 Functional-Min2
# 242 Functional-Mod
# 243 Functional-Sev
# 244 Functional-Typ
# 245 FireplaceQu-Ex
# 246 FireplaceQu-Fa
# 247 FireplaceQu-Gd
# 248 FireplaceQu-Null_Value
# 249 FireplaceQu-Po
# 250 FireplaceQu-TA
# 251 GarageType-2Types
# 252 GarageType-Attchd
# 253 GarageType-Basment
# 254 GarageType-BuiltIn
# 255 GarageType-CarPort
# 256 GarageType-Detchd
# 257 GarageType-Null_Value
# 258 GarageYrBlt_ISNULL-0
# 259 GarageYrBlt_ISNULL-1
# 260 GarageFinish-Fin
# 261 GarageFinish-Null_Value
# 262 GarageFinish-RFn
# 263 GarageFinish-Unf
# 264 GarageQual-Ex
# 265 GarageQual-Fa
# 266 GarageQual-Gd
# 267 GarageQual-Null_Value
# 268 GarageQual-Po
# 269 GarageQual-TA
# 270 GarageCond-Ex
# 271 GarageCond-Fa
# 272 GarageCond-Gd
# 273 GarageCond-Null_Value
# 274 GarageCond-Po
# 275 GarageCond-TA
# 276 PavedDrive-N
# 277 PavedDrive-P
# 278 PavedDrive-Y
# 279 PoolQC-Ex
# 280 PoolQC-Fa
# 281 PoolQC-Gd
# 282 PoolQC-Null_Value
# 283 Fence-GdPrv
# 284 Fence-GdWo
# 285 Fence-MnPrv
# 286 Fence-MnWw
# 287 Fence-Null_Value
# 288 MiscFeature-Gar2
# 289 MiscFeature-Null_Value
# 290 MiscFeature-Othr
# 291 MiscFeature-Shed
# 292 MiscFeature-TenC
# 293 MoSold-1
# 294 MoSold-2
# 295 MoSold-3
# 296 MoSold-4
# 297 MoSold-5
# 298 MoSold-6
# 299 MoSold-7
# 300 MoSold-8
# 301 MoSold-9
# 302 MoSold-10
# 303 MoSold-11
# 304 MoSold-12
# 305 SaleType-COD
# 306 SaleType-CWD
# 307 SaleType-Con
# 308 SaleType-ConLD
# 309 SaleType-ConLI
# 310 SaleType-ConLw
# 311 SaleType-New
# 312 SaleType-Oth
# 313 SaleType-WD
# 314 SaleCondition-Abnorml
# 315 SaleCondition-AdjLand
# 316 SaleCondition-Alloca
# 317 SaleCondition-Family
# 318 SaleCondition-Normal
# 319 SaleCondition-Partial
# 320 LotFrontage
# 321 LotArea
# 322 YearBuilt
# 323 YearRemodAdd
# 324 MasVnrArea
# 325 BsmtFinSF1
# 326 BsmtFinSF2
# 327 BsmtUnfSF
# 328 TotalBsmtSF
# 329 FirstFlrSF
# 330 SecondFlrSF
# 331 LowQualFinSF
# 332 GrLivArea
# 333 BsmtFullBath
# 334 BsmtHalfBath
# 335 FullBath
# 336 HalfBath
# 337 BedroomAbvGr
# 338 KitchenAbvGr
# 339 TotRmsAbvGrd
# 340 Fireplaces
# 341 GarageYrBlt
# 342 GarageCars
# 343 GarageArea
# 344 WoodDeckSF
# 345 OpenPorchSF
# 346 EnclosedPorch
# 347 ThreeSsnPorch
# 348 ScreenPorch
# 349 PoolArea
# 350 MiscVal
# 351 YrSold
# 352 SalePrice

# %% [markdown]
# Split the data into a training and validation set, with the validation set containing p_val_size (defaulted to 0.2) portion of the data.

# %%
warnings.filterwarnings('ignore')

predictors_enc = np.arange(352)
target_enc = 352
 
X_train, X_val, Y_train, Y_val = ModelTools.TrainHoldSplit(dataset_enc,predictors_enc,target_enc,p_val_size=0.25)

# %% [markdown]
# <a name="linear-univariate-analysis"></a>
# ## Linear Univariate Analysis
#
# A univariate linear analysis gives us a basic intuition of the relationship between our predictors and our target variable. However it does not account for any correlations that exist, therefore it is not recommended for variable selection. For each predictor we will fit a linear model on the training set and compute the performance on the validation set. For binary classification problems, set p_model = 'binary' for logistic regression; for continuous regression problems, set p_model = 'continuous' and choose the appropriate distribution and link function (defaulted to gamma and log link).
# <br>
# A list of the top p_top_k_features (defaulted to 5) features will be shown, ordered by their performance on the validation set, and below a graph of the univariate fit will be given along with additional statistics. For each categorical predictor, the fitted value and 95% confidence interval are graphed on the primary axis. On the secondary axis, the weight/count in each level is given as a bar chart. For continuous predictors, the fitted value is graphed with either a scatter plot of the data or p_n_buckets (defaulted to 20) average values, for continuous and classification target variables respectively.

# %%
warnings.filterwarnings('ignore')

features = ModelTools.FeatureIndexes(dataset, dataset_enc, target_enc)
ModelTools.UnivariateAnalysis(features, X_train, Y_train, X_val, Y_val, p_top_k_features=30, p_model='continuous', p_metric = 'L1 Error', p_n_buckets = 10)
# Out:
#         Variable  Validation Error
# 17   OverallQual      30455.629122
# 12  Neighborhood      37820.327500
# 28     ExterQual      39290.158170
# 31      BsmtQual      39511.808730
# 54   KitchenQual      40068.269069
# 63    GarageCars      41887.406493
# 47     GrLivArea      42842.677781
# 64    GarageArea      43862.178354
# 62  GarageFinish      44262.162959
# 50      FullBath      45355.859632
# 19     YearBuilt      45885.123812
# 59    GarageType      46565.689728
# 44    FirstFlrSF      46937.378481
# 0     MSSubClass      47831.339373
# 20  YearRemodAdd      47957.068362
# 58   FireplaceQu      48316.251942
# 30    Foundation      48851.875171
# 55  TotRmsAbvGrd      49072.711175
# 39   TotalBsmtSF      50759.505502
# 57    Fireplaces      50763.455976
# 26    MasVnrArea      50848.704183
# 41     HeatingQC      51047.457528
# 34  BsmtFinType1      51337.733114
# 33  BsmtExposure      51469.755958
# 23   Exterior1st      51816.044438
# 1       MSZoning      52319.157344
# 24   Exterior2nd      52505.011180
# 68    WoodDeckSF      52588.428641
# 69   OpenPorchSF      52598.523408
# 18   OverallCond      52877.810136
# Feature: OverallQual
# Validation Error: 30455.629121696315
# Training AIC: 26245.5858203
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1085
# Model Family:                   Gamma   Df Model:                            9
# Link Function:                    log   Scale:                 0.0523753009458
# Method:                          IRLS   Log-Likelihood:                -13113.
# Date:                Sat, 06 Jan 2018   Deviance:                       57.839
# Time:                        20:28:45   Pearson chi2:                     56.8
# No. Iterations:                     5
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# OverallQual-1     10.8228      0.162     66.879      0.000      10.506      11.140
# OverallQual-2     10.8546      0.132     82.150      0.000      10.596      11.114
# OverallQual-3     11.3814      0.059    192.609      0.000      11.266      11.497
# OverallQual-4     11.6103      0.025    473.194      0.000      11.562      11.658
# OverallQual-5     11.8046      0.013    890.422      0.000      11.779      11.831
# OverallQual-6     11.9902      0.014    886.024      0.000      11.964      12.017
# OverallQual-7     12.2556      0.015    827.888      0.000      12.227      12.285
# OverallQual-8     12.5370      0.020    617.350      0.000      12.497      12.577
# OverallQual-9     12.8564      0.043    297.259      0.000      12.772      12.941
# OverallQual-10    13.0024      0.072    179.663      0.000      12.861      13.144
# ==================================================================================
# Feature: Neighborhood
# Validation Error: 37820.32750009071
# Training AIC: 26577.0896281
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1070
# Model Family:                   Gamma   Df Model:                           24
# Link Function:                    log   Scale:                 0.0768100135849
# Method:                          IRLS   Log-Likelihood:                -13264.
# Date:                Sat, 06 Jan 2018   Deviance:                       75.435
# Time:                        20:28:46   Pearson chi2:                     82.2
# No. Iterations:                     4
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Neighborhood-Blmngtn    12.1969      0.080    152.451      0.000      12.040      12.354
# Neighborhood-Blueste    11.8314      0.196     60.373      0.000      11.447      12.215
# Neighborhood-BrDale     11.5436      0.080    144.286      0.000      11.387      11.700
# Neighborhood-BrkSide    11.7424      0.042    281.044      0.000      11.661      11.824
# Neighborhood-ClearCr    12.2610      0.055    221.201      0.000      12.152      12.370
# Neighborhood-CollgCr    12.2216      0.026    464.600      0.000      12.170      12.273
# Neighborhood-Crawfor    12.2894      0.046    269.725      0.000      12.200      12.379
# Neighborhood-Edwards    11.7345      0.032    369.115      0.000      11.672      11.797
# Neighborhood-Gilbert    12.1605      0.035    342.696      0.000      12.091      12.230
# Neighborhood-IDOTRR     11.4355      0.054    210.393      0.000      11.329      11.542
# Neighborhood-MeadowV    11.5427      0.077    150.166      0.000      11.392      11.693
# Neighborhood-Mitchel    11.9449      0.044    269.158      0.000      11.858      12.032
# Neighborhood-NAmes      11.8976      0.022    548.081      0.000      11.855      11.940
# Neighborhood-NPkVill    11.8576      0.098    121.013      0.000      11.666      12.050
# Neighborhood-NWAmes     12.1662      0.038    322.584      0.000      12.092      12.240
# Neighborhood-NoRidge    12.7270      0.050    255.680      0.000      12.629      12.825
# Neighborhood-NridgHt    12.6562      0.037    344.772      0.000      12.584      12.728
# Neighborhood-OldTown    11.7649      0.031    377.304      0.000      11.704      11.826
# Neighborhood-SWISU      11.8271      0.062    190.847      0.000      11.706      11.949
# Neighborhood-Sawyer     11.8238      0.035    341.303      0.000      11.756      11.892
# Neighborhood-SawyerW    12.0977      0.041    292.820      0.000      12.017      12.179
# Neighborhood-Somerst    12.3402      0.035    353.413      0.000      12.272      12.409
# Neighborhood-StoneBr    12.6414      0.069    182.452      0.000      12.506      12.777
# Neighborhood-Timber     12.3959      0.050    249.029      0.000      12.298      12.493
# Neighborhood-Veenker    12.3437      0.113    109.096      0.000      12.122      12.565
# ========================================================================================
# Feature: ExterQual
# Validation Error: 39290.15817012798
# Training AIC: 26821.9889261
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1091
# Model Family:                   Gamma   Df Model:                            3
# Link Function:                    log   Scale:                 0.0941193408073
# Method:                          IRLS   Log-Likelihood:                -13407.
# Date:                Sat, 06 Jan 2018   Deviance:                       98.195
# Time:                        20:28:47   Pearson chi2:                     103.
# No. Iterations:                     4
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ExterQual-Ex    12.8195      0.052    247.210      0.000      12.718      12.921
# ExterQual-Fa    11.3691      0.089    128.375      0.000      11.196      11.543
# ExterQual-Gd    12.3559      0.016    764.165      0.000      12.324      12.388
# ExterQual-TA    11.8898      0.012   1016.556      0.000      11.867      11.913
# ================================================================================
# Feature: BsmtQual
# Validation Error: 39511.80873016666
# Training AIC: 26811.9461073
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1090
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                  0.092874257017
# Method:                          IRLS   Log-Likelihood:                -13401.
# Date:                Sat, 06 Jan 2018   Deviance:                       97.153
# Time:                        20:28:47   Pearson chi2:                     101.
# No. Iterations:                     4
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# BsmtQual-Ex            12.6947      0.032    392.979      0.000      12.631      12.758
# BsmtQual-Fa            11.6769      0.062    187.709      0.000      11.555      11.799
# BsmtQual-Gd            12.2247      0.014    854.711      0.000      12.197      12.253
# BsmtQual-Null_Value    11.5550      0.061    189.579      0.000      11.436      11.674
# BsmtQual-TA            11.8568      0.014    872.577      0.000      11.830      11.883
# =======================================================================================
# Feature: KitchenQual
# Validation Error: 40068.26906888359
# Training AIC: 26823.9421288
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1091
# Model Family:                   Gamma   Df Model:                            3
# Link Function:                    log   Scale:                 0.0917971474117
# Method:                          IRLS   Log-Likelihood:                -13408.
# Date:                Sat, 06 Jan 2018   Deviance:                       98.502
# Time:                        20:28:48   Pearson chi2:                     100.
# No. Iterations:                     4
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# KitchenQual-Ex    12.6800      0.035    360.014      0.000      12.611      12.749
# KitchenQual-Fa    11.5827      0.054    212.851      0.000      11.476      11.689
# KitchenQual-Gd    12.2746      0.015    837.155      0.000      12.246      12.303
# KitchenQual-TA    11.8561      0.013    928.500      0.000      11.831      11.881
# ==================================================================================
# Feature: GarageCars
# Validation Error: 41887.40649338942
# Training AIC: 26715.0533257
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                 0.0830927372051
# Method:                          IRLS   Log-Likelihood:                -13356.
# Date:                Sat, 06 Jan 2018   Deviance:                       89.642
# Time:                        20:28:48   Pearson chi2:                     90.8
# No. Iterations:                     6
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3775      0.023    501.403      0.000      11.333      11.422
# GarageCars     0.3886      0.012     32.725      0.000       0.365       0.412
# ==============================================================================
# Feature: GrLivArea
# Validation Error: 42842.6777812274
# Training AIC: 26621.3204284
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                 0.0710573459383
# Method:                          IRLS   Log-Likelihood:                -13309.
# Date:                Sat, 06 Jan 2018   Deviance:                       82.329
# Time:                        20:28:49   Pearson chi2:                     77.7
# No. Iterations:                     6
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.1756      0.025    445.993      0.000      11.126      11.225
# GrLivArea      0.0006   1.56e-05     37.268      0.000       0.001       0.001
# ==============================================================================
# Feature: GarageArea
# Validation Error: 43862.178354316486
# Training AIC: 26784.6490428
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.087767581638
# Method:                          IRLS   Log-Likelihood:                -13390.
# Date:                Sat, 06 Jan 2018   Deviance:                       95.459
# Time:                        20:28:49   Pearson chi2:                     95.9
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.4388      0.022    520.078      0.000      11.396      11.482
# GarageArea     0.0013   4.26e-05     31.213      0.000       0.001       0.001
# ==============================================================================
# Feature: GarageFinish
# Validation Error: 44262.16295878877
# Training AIC: 27009.0887665
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1091
# Model Family:                   Gamma   Df Model:                            3
# Link Function:                    log   Scale:                  0.121460078451
# Method:                          IRLS   Log-Likelihood:                -13501.
# Date:                Sat, 06 Jan 2018   Deviance:                       114.92
# Time:                        20:28:50   Pearson chi2:                     133.
# No. Iterations:                     4
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# GarageFinish-Fin           12.3695      0.021    577.774      0.000      12.328      12.411
# GarageFinish-Null_Value    11.5011      0.047    246.954      0.000      11.410      11.592
# GarageFinish-RFn           12.2252      0.019    628.482      0.000      12.187      12.263
# GarageFinish-Unf           11.8666      0.016    724.698      0.000      11.834      11.899
# ===========================================================================================
# Feature: FullBath
# Validation Error: 45355.85963173136
# Training AIC: 26977.4771382
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.112436355781
# Method:                          IRLS   Log-Likelihood:                -13487.
# Date:                Sat, 06 Jan 2018   Deviance:                       112.97
# Time:                        20:28:50   Pearson chi2:                     123.
# No. Iterations:                     5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3676      0.031    368.762      0.000      11.307      11.428
# FullBath       0.4501      0.019     24.259      0.000       0.414       0.487
# ==============================================================================
# Feature: YearBuilt
# Validation Error: 45885.12381203792
# Training AIC: 27104.3940733
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.141716852484
# Method:                          IRLS   Log-Likelihood:                -13550.
# Date:                Sat, 06 Jan 2018   Deviance:                       123.70
# Time:                        20:28:51   Pearson chi2:                     155.
# No. Iterations:                     6
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3379      0.743     -3.148      0.002      -3.794      -0.882
# YearBuilt      0.0073      0.000     19.411      0.000       0.007       0.008
# ==============================================================================
# Feature: GarageType
# Validation Error: 46565.68972796471
# Training AIC: 27080.2122612
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1088
# Model Family:                   Gamma   Df Model:                            6
# Link Function:                    log   Scale:                  0.129586952618
# Method:                          IRLS   Log-Likelihood:                -13533.
# Date:                Sat, 06 Jan 2018   Deviance:                       121.67
# Time:                        20:28:51   Pearson chi2:                     141.
# No. Iterations:                     4
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# GarageType-2Types        11.9269      0.147     81.156      0.000      11.639      12.215
# GarageType-Attchd        12.2148      0.014    869.736      0.000      12.187      12.242
# GarageType-Basment       11.9629      0.100    119.820      0.000      11.767      12.159
# GarageType-BuiltIn       12.4513      0.044    285.225      0.000      12.366      12.537
# GarageType-CarPort       11.5782      0.161     71.919      0.000      11.263      11.894
# GarageType-Detchd        11.8082      0.021    558.601      0.000      11.767      11.850
# GarageType-Null_Value    11.5011      0.048    239.085      0.000      11.407      11.595
# =========================================================================================
# Feature: FirstFlrSF
# Validation Error: 46937.378480841064
# Training AIC: 26951.0937225
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.102964993189
# Method:                          IRLS   Log-Likelihood:                -13474.
# Date:                Sat, 06 Jan 2018   Deviance:                       110.84
# Time:                        20:28:52   Pearson chi2:                     113.
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3078      0.031    359.246      0.000      11.246      11.370
# FirstFlrSF     0.0007   2.58e-05     25.548      0.000       0.001       0.001
# ==============================================================================
# Feature: MSSubClass
# Validation Error: 47831.33937275311
# Training AIC: 27104.2723109
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1080
# Model Family:                   Gamma   Df Model:                           14
# Link Function:                    log   Scale:                  0.131730113452
# Method:                          IRLS   Log-Likelihood:                -13537.
# Date:                Sat, 06 Jan 2018   Deviance:                       122.32
# Time:                        20:28:53   Pearson chi2:                     142.
# No. Iterations:                     4
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MSSubClass-20     12.1254      0.018    670.664      0.000      12.090      12.161
# MSSubClass-30     11.4627      0.050    227.744      0.000      11.364      11.561
# MSSubClass-40     12.1099      0.210     57.791      0.000      11.699      12.521
# MSSubClass-45     11.5946      0.109    105.952      0.000      11.380      11.809
# MSSubClass-50     11.8609      0.035    334.865      0.000      11.791      11.930
# MSSubClass-60     12.3916      0.024    520.031      0.000      12.345      12.438
# MSSubClass-70     12.0215      0.052    229.477      0.000      11.919      12.124
# MSSubClass-75     12.2162      0.109    111.633      0.000      12.002      12.431
# MSSubClass-80     12.0112      0.058    206.669      0.000      11.897      12.125
# MSSubClass-85     11.8985      0.097    122.663      0.000      11.708      12.089
# MSSubClass-90     11.8120      0.060    197.962      0.000      11.695      11.929
# MSSubClass-120    12.1837      0.046    262.181      0.000      12.093      12.275
# MSSubClass-160    11.8279      0.051    232.728      0.000      11.728      11.927
# MSSubClass-180    11.5927      0.162     71.421      0.000      11.275      11.911
# MSSubClass-190    11.7812      0.076    155.672      0.000      11.633      11.930
# ==================================================================================
# Feature: YearRemodAdd
# Validation Error: 47957.06836174677
# Training AIC: 27045.0176307
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.120242725288
# Method:                          IRLS   Log-Likelihood:                -13521.
# Date:                Sat, 06 Jan 2018   Deviance:                       119.92
# Time:                        20:28:53   Pearson chi2:                     131.
# No. Iterations:                     5
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -11.1065      1.011    -10.983      0.000     -13.089      -9.125
# YearRemodAdd     0.0117      0.001     22.927      0.000       0.011       0.013
# ================================================================================
# Feature: FireplaceQu
# Validation Error: 48316.25194161369
# Training AIC: 27058.6235626
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1089
# Model Family:                   Gamma   Df Model:                            5
# Link Function:                    log   Scale:                  0.115852278008
# Method:                          IRLS   Log-Likelihood:                -13523.
# Date:                Sat, 06 Jan 2018   Deviance:                       121.01
# Time:                        20:28:54   Pearson chi2:                     126.
# No. Iterations:                     4
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# FireplaceQu-Ex            12.7699      0.080    159.174      0.000      12.613      12.927
# FireplaceQu-Fa            12.0247      0.064    186.939      0.000      11.899      12.151
# FireplaceQu-Gd            12.3256      0.021    600.514      0.000      12.285      12.366
# FireplaceQu-Null_Value    11.8599      0.015    795.330      0.000      11.831      11.889
# FireplaceQu-Po            11.7793      0.085    138.429      0.000      11.612      11.946
# FireplaceQu-TA            12.2418      0.022    553.689      0.000      12.198      12.285
# ==========================================================================================
# Feature: Foundation
# Validation Error: 48851.87517098224
# Training AIC: 27100.2814534
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1089
# Model Family:                   Gamma   Df Model:                            5
# Link Function:                    log   Scale:                   0.12877357071
# Method:                          IRLS   Log-Likelihood:                -13544.
# Date:                Sat, 06 Jan 2018   Deviance:                       124.65
# Time:                        20:28:55   Pearson chi2:                     140.
# No. Iterations:                     4
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Foundation-BrkTil    11.7872      0.034    344.505      0.000      11.720      11.854
# Foundation-CBlock    11.9192      0.016    726.942      0.000      11.887      11.951
# Foundation-PConc     12.3267      0.016    752.582      0.000      12.295      12.359
# Foundation-Slab      11.5506      0.082    140.303      0.000      11.389      11.712
# Foundation-Stone     12.0195      0.147     82.044      0.000      11.732      12.307
# Foundation-Wood      12.4292      0.359     34.636      0.000      11.726      13.133
# =====================================================================================
# Feature: TotRmsAbvGrd
# Validation Error: 49072.71117495368
# Training AIC: 27059.7325727
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.113667737607
# Method:                          IRLS   Log-Likelihood:                -13528.
# Date:                Sat, 06 Jan 2018   Deviance:                       122.17
# Time:                        20:28:55   Pearson chi2:                     124.
# No. Iterations:                     5
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           11.1578      0.042    264.133      0.000      11.075      11.241
# TotRmsAbvGrd     0.1404      0.006     22.447      0.000       0.128       0.153
# ================================================================================
# Feature: TotalBsmtSF
# Validation Error: 50759.50550243285
# Training AIC: 26906.6886467
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.100472074222
# Method:                          IRLS   Log-Likelihood:                -13451.
# Date:                Sat, 06 Jan 2018   Deviance:                       106.43
# Time:                        20:28:55   Pearson chi2:                     110.
# No. Iterations:                     4
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          11.4186      0.026    432.324      0.000      11.367      11.470
# TotalBsmtSF     0.0006   2.33e-05     26.501      0.000       0.001       0.001
# ===============================================================================
# Feature: Fireplaces
# Validation Error: 50763.45597602006
# Training AIC: 27169.0044608
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.131109763061
# Method:                          IRLS   Log-Likelihood:                -13583.
# Date:                Sat, 06 Jan 2018   Deviance:                       134.34
# Time:                        20:28:56   Pearson chi2:                     143.
# No. Iterations:                     5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.8853      0.015    787.985      0.000      11.856      11.915
# Fireplaces     0.3269      0.017     19.097      0.000       0.293       0.360
# ==============================================================================
# Feature: MasVnrArea
# Validation Error: 50848.704183364454
# Training AIC: 27226.0558583
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.133833421225
# Method:                          IRLS   Log-Likelihood:                -13611.
# Date:                Sat, 06 Jan 2018   Deviance:                       141.68
# Time:                        20:28:56   Pearson chi2:                     146.
# No. Iterations:                     5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.9837      0.013    943.700      0.000      11.959      12.009
# MasVnrArea     0.0010   6.02e-05     16.523      0.000       0.001       0.001
# ==============================================================================
# Feature: HeatingQC
# Validation Error: 51047.457528151295
# Training AIC: 27203.1173215
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1090
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                  0.139127725372
# Method:                          IRLS   Log-Likelihood:                -13597.
# Date:                Sat, 06 Jan 2018   Deviance:                       137.22
# Time:                        20:28:57   Pearson chi2:                     152.
# No. Iterations:                     4
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# HeatingQC-Ex    12.2808      0.016    769.338      0.000      12.250      12.312
# HeatingQC-Fa    11.7009      0.061    190.816      0.000      11.581      11.821
# HeatingQC-Gd    11.9589      0.028    432.533      0.000      11.905      12.013
# HeatingQC-Po    11.3737      0.373     30.493      0.000      10.643      12.105
# HeatingQC-TA    11.8748      0.021    577.456      0.000      11.835      11.915
# ================================================================================
# Feature: BsmtFinType1
# Validation Error: 51337.7331142034
# Training AIC: 27202.3668168
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1088
# Model Family:                   Gamma   Df Model:                            6
# Link Function:                    log   Scale:                  0.137568272729
# Method:                          IRLS   Log-Likelihood:                -13594.
# Date:                Sat, 06 Jan 2018   Deviance:                       136.76
# Time:                        20:28:58   Pearson chi2:                     150.
# No. Iterations:                     4
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# BsmtFinType1-ALQ           11.9956      0.029    412.909      0.000      11.939      12.052
# BsmtFinType1-BLQ           11.9126      0.034    348.890      0.000      11.846      11.980
# BsmtFinType1-GLQ           12.3764      0.021    583.708      0.000      12.335      12.418
# BsmtFinType1-LwQ           11.9384      0.050    236.528      0.000      11.839      12.037
# BsmtFinType1-Null_Value    11.5550      0.074    155.769      0.000      11.410      11.700
# BsmtFinType1-Rec           11.8917      0.037    319.007      0.000      11.819      11.965
# BsmtFinType1-Unf           12.0418      0.020    589.778      0.000      12.002      12.082
# ===========================================================================================
# Feature: BsmtExposure
# Validation Error: 51469.75595836937
# Training AIC: 27328.38583
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1090
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                  0.152142740303
# Method:                          IRLS   Log-Likelihood:                -13659.
# Date:                Sat, 06 Jan 2018   Deviance:                       153.85
# Time:                        20:28:58   Pearson chi2:                     166.
# No. Iterations:                     4
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# BsmtExposure-Av            12.2259      0.031    398.945      0.000      12.166      12.286
# BsmtExposure-Gd            12.4549      0.040    314.486      0.000      12.377      12.533
# BsmtExposure-Mn            12.1493      0.041    298.758      0.000      12.070      12.229
# BsmtExposure-No            12.0250      0.015    826.653      0.000      11.996      12.053
# BsmtExposure-Null_Value    11.5550      0.078    148.120      0.000      11.402      11.708
# ===========================================================================================
# Feature: Exterior1st
# Validation Error: 51816.04443763669
# Training AIC: 27278.2469123
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1080
# Model Family:                   Gamma   Df Model:                           14
# Link Function:                    log   Scale:                  0.153138705527
# Method:                          IRLS   Log-Likelihood:                -13624.
# Date:                Sat, 06 Jan 2018   Deviance:                       143.00
# Time:                        20:28:59   Pearson chi2:                     165.
# No. Iterations:                     5
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Exterior1st-AsbShng    11.5694      0.101    114.503      0.000      11.371      11.767
# Exterior1st-AsphShn    11.5129      0.391     29.420      0.000      10.746      12.280
# Exterior1st-BrkComm    11.0021      0.391     28.115      0.000      10.235      11.769
# Exterior1st-BrkFace    12.2185      0.064    189.922      0.000      12.092      12.345
# Exterior1st-CBlock     11.5617      0.391     29.545      0.000      10.795      12.329
# Exterior1st-CemntBd    12.3198      0.058    213.521      0.000      12.207      12.433
# Exterior1st-HdBoard    11.9991      0.030    393.865      0.000      11.939      12.059
# Exterior1st-ImStucc    12.4761      0.391     31.881      0.000      11.709      13.243
# Exterior1st-MetalSd    11.9121      0.032    374.053      0.000      11.850      11.974
# Exterior1st-Plywood    12.0714      0.041    295.876      0.000      11.991      12.151
# Exterior1st-Stone      12.4627      0.277     45.038      0.000      11.920      13.005
# Exterior1st-Stucco     12.1146      0.095    127.641      0.000      11.929      12.301
# Exterior1st-VinylSd    12.2831      0.020    615.081      0.000      12.244      12.322
# Exterior1st-Wd Sdng    11.8727      0.031    384.963      0.000      11.812      11.933
# Exterior1st-WdShing    11.8447      0.085    138.705      0.000      11.677      12.012
# =======================================================================================
# Feature: MSZoning
# Validation Error: 52319.157343698476
# Training AIC: 27323.6452312
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1090
# Model Family:                   Gamma   Df Model:                            4
# Link Function:                    log   Scale:                  0.166677610553
# Method:                          IRLS   Log-Likelihood:                -13657.
# Date:                Sat, 06 Jan 2018   Deviance:                       150.67
# Time:                        20:29:00   Pearson chi2:                     182.
# No. Iterations:                     4
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# MSZoning-C (all)    11.1677      0.136     82.063      0.000      10.901      11.434
# MSZoning-FV         12.2775      0.062    199.479      0.000      12.157      12.398
# MSZoning-RH         11.7440      0.109    107.632      0.000      11.530      11.958
# MSZoning-RL         12.1594      0.014    879.992      0.000      12.132      12.186
# MSZoning-RM         11.7384      0.033    357.961      0.000      11.674      11.803
# ====================================================================================
# Feature: Exterior2nd
# Validation Error: 52505.01118037577
# Training AIC: 27287.9587203
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1079
# Model Family:                   Gamma   Df Model:                           15
# Link Function:                    log   Scale:                  0.152799496012
# Method:                          IRLS   Log-Likelihood:                -13628.
# Date:                Sat, 06 Jan 2018   Deviance:                       144.24
# Time:                        20:29:01   Pearson chi2:                     165.
# No. Iterations:                     5
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Exterior2nd-AsbShng    11.6397      0.095    122.773      0.000      11.454      11.825
# Exterior2nd-AsphShn    11.5129      0.391     29.453      0.000      10.747      12.279
# Exterior2nd-Brk Cmn    11.7753      0.175     67.359      0.000      11.433      12.118
# Exterior2nd-BrkFace    12.2380      0.092    132.826      0.000      12.057      12.419
# Exterior2nd-CBlock     11.5617      0.391     29.577      0.000      10.796      12.328
# Exterior2nd-CmentBd    12.3400      0.058    214.108      0.000      12.227      12.453
# Exterior2nd-HdBoard    12.0263      0.031    381.797      0.000      11.965      12.088
# Exterior2nd-ImStucc    12.2594      0.138     88.706      0.000      11.989      12.530
# Exterior2nd-MetalSd    11.9107      0.032    369.433      0.000      11.848      11.974
# Exterior2nd-Other      12.6729      0.391     32.420      0.000      11.907      13.439
# Exterior2nd-Plywood    12.0376      0.036    335.932      0.000      11.967      12.108
# Exterior2nd-Stone      11.9024      0.195     60.898      0.000      11.519      12.286
# Exterior2nd-Stucco     12.0857      0.098    123.672      0.000      11.894      12.277
# Exterior2nd-VinylSd    12.2878      0.020    607.111      0.000      12.248      12.327
# Exterior2nd-Wd Sdng    11.8854      0.031    379.765      0.000      11.824      11.947
# Exterior2nd-Wd Shng    11.8665      0.073    163.479      0.000      11.724      12.009
# =======================================================================================
# Feature: WoodDeckSF
# Validation Error: 52588.42864115136
# Training AIC: 27386.5195678
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.167983987865
# Method:                          IRLS   Log-Likelihood:                -13691.
# Date:                Sat, 06 Jan 2018   Deviance:                       161.94
# Time:                        20:29:01   Pearson chi2:                     184.
# No. Iterations:                     5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.9978      0.015    778.187      0.000      11.968      12.028
# WoodDeckSF     0.0010   9.74e-05     10.716      0.000       0.001       0.001
# ==============================================================================
# Feature: OpenPorchSF
# Validation Error: 52598.5234083153
# Training AIC: 27365.8961554
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1093
# Model Family:                   Gamma   Df Model:                            1
# Link Function:                    log   Scale:                  0.162730872913
# Method:                          IRLS   Log-Likelihood:                -13681.
# Date:                Sat, 06 Jan 2018   Deviance:                       159.34
# Time:                        20:29:02   Pearson chi2:                     178.
# No. Iterations:                     8
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          11.9903      0.015    805.699      0.000      11.961      12.019
# OpenPorchSF     0.0022      0.000     12.265      0.000       0.002       0.003
# ===============================================================================
# Feature: OverallCond
# Validation Error: 52877.81013581455
# Training AIC: 27318.3452852
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   No. Observations:                 1095
# Model:                            GLM   Df Residuals:                     1086
# Model Family:                   Gamma   Df Model:                            8
# Link Function:                    log   Scale:                  0.159569509482
# Method:                          IRLS   Log-Likelihood:                -13650.
# Date:                Sat, 06 Jan 2018   Deviance:                       149.94
# Time:                        20:29:02   Pearson chi2:                     173.
# No. Iterations:                     5
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# OverallCond-1    11.0186      0.399     27.584      0.000      10.236      11.802
# OverallCond-2    11.8635      0.179     66.408      0.000      11.513      12.214
# OverallCond-3    11.3779      0.097    117.438      0.000      11.188      11.568
# OverallCond-4    11.7211      0.058    203.288      0.000      11.608      11.834
# OverallCond-5    12.2187      0.016    752.366      0.000      12.187      12.251
# OverallCond-6    11.9517      0.028    425.238      0.000      11.897      12.007
# OverallCond-7    11.9870      0.033    362.586      0.000      11.922      12.052
# OverallCond-8    11.9820      0.054    222.453      0.000      11.876      12.088
# OverallCond-9    12.3293      0.100    123.459      0.000      12.134      12.525
# =================================================================================

# %% [markdown]
# <a name="random-forest-univariate-analysis"></a>
# ## Random Forest Univariate Analysis
#
# The idea here is to start with all the predictors and iteratively remove one variable at a time, and calculate the loss in overall fit. A larger loss in fit implies a higher marginal importance of the variable. This gives a slightly different perspective than the linear univariate analysis above. Given a group of correlated and highly predictive variables, they will all come through as predictive in the section above since one variable is being fitted at a time, whereas here removing one of these variables should not affect the overall fit too much since the other correlated variables should pick up the lost signal. Here the focus is more on unique contribution of each variable.
# <br>
# To avoid over-fitting, p_cross_validations (defaulted to 5) will be used for cross-validation using p_validation_fraction (defaulted to 0.25) for the test set size. In order to reduce run-time, instead of actually removing variables and re-fitting, we will fit the model on the training set and then randomize the variable we would like to remove in order to break any relationship between it and the target variable. This allows us to fit the model once (for each cross-validation set) and infer for each of our predictors instead of re-fitting it for each of our predictors.

# %%
ModelTools.UnivariateRandomForestPermutations(p_features = features,
                                              p_X_train = X_train,
                                              p_Y_train = Y_train,
                                              p_regression = True,
                                              p_metric = 'L1 Error')
# Out:
# *********Features sorted by their L1 error based score:**********
# GrLivArea: 0.41510
# YearBuilt: 0.13945
# GarageCars: 0.12920
# TotalBsmtSF: 0.10542
# FirstFlrSF: 0.06773
# BsmtFinSF1: 0.05084
# YearRemodAdd: 0.05081
# GarageArea: 0.04463
# ExterQual: 0.03958
# OverallQual: 0.03673
# LotArea: 0.03540
# BsmtQual: 0.02911
# KitchenQual: 0.01856
# MasVnrArea: 0.01487
# CentralAir: 0.01279
# Neighborhood: 0.00952
# WoodDeckSF: 0.00931
# BsmtUnfSF: 0.00906
# Fireplaces: 0.00898
# FireplaceQu: 0.00855
# GarageYrBlt: 0.00834
# BsmtExposure: 0.00614
# SecondFlrSF: 0.00579
# OverallCond: 0.00530
# MSZoning: 0.00504
# OpenPorchSF: 0.00432
# GarageType: 0.00416
# KitchenAbvGr: 0.00404
# TotRmsAbvGrd: 0.00374
# BsmtFinType1: 0.00340
# BldgType: 0.00282
# BedroomAbvGr: 0.00279
# HalfBath: 0.00271
# FullBath: 0.00254
# MoSold: 0.00238
# LotShape: 0.00230
# BsmtFullBath: 0.00216
# HeatingQC: 0.00201
# SaleType: 0.00194
# LandSlope: 0.00189
# Exterior1st: 0.00180
# MSSubClass: 0.00165
# SaleCondition: 0.00162
# GarageQual: 0.00154
# RoofMatl: 0.00148
# BsmtCond: 0.00144
# LotConfig: 0.00133
# ScreenPorch: 0.00132
# ExterCond: 0.00119
# LandContour: 0.00115
# LotFrontage: 0.00112
# Condition1: 0.00106
# Functional: 0.00091
# GarageCond: 0.00072
# PavedDrive: 0.00059
# GarageYrBlt_ISNULL: 0.00058
# BsmtFinType2: 0.00050
# LotFrontage_ISNULL: 0.00042
# MasVnrType: 0.00041
# BsmtFinSF2: 0.00036
# GarageFinish: 0.00029
# Heating: 0.00015
# Fence: 0.00012
# Alley: 0.00005
# LowQualFinSF: 0.00003
# ThreeSsnPorch: 0.00001
# Street: 0.00000
# Condition2: 0.00000
# PoolArea: 0.00000
# PoolQC: 0.00000
# Utilities: 0.00000
# MasVnrArea_ISNULL: -0.00000
# MiscFeature: -0.00002
# Foundation: -0.00002
# EnclosedPorch: -0.00006
# MiscVal: -0.00009
# Electrical: -0.00009
# YrSold: -0.00034
# BsmtHalfBath: -0.00034
# HouseStyle: -0.00046
# RoofStyle: -0.00097
# Exterior2nd: -0.00142

# %% [markdown]
# <a name="gradient-boosting-univariate-analysis"></a>
# ## Gradient Boosting Univariate Analysis
#
# This section is analagous to the Random Forest Univariate Analysis section above, except using Gradient Boosting models instead of Random Forest models.

# %%
ModelTools.UnivariateGradientBoostingPermutations(p_features = features,
                                                  p_X_train = X_train,
                                                  p_Y_train = Y_train,
                                                  p_regression = True,
                                                  p_metric = 'L1 Error')
# Out:
# *********Features sorted by their L1 error based score:**********
# GrLivArea: 0.22440
# TotalBsmtSF: 0.07276
# KitchenQual: 0.04017
# FirstFlrSF: 0.03700
# YearRemodAdd: 0.02914
# GarageYrBlt: 0.02442
# OverallQual: 0.02232
# YearBuilt: 0.02052
# BsmtFinSF1: 0.01896
# LotArea: 0.01855
# GarageCars: 0.01352
# BsmtFinType1: 0.01313
# Fireplaces: 0.01219
# GarageArea: 0.01183
# WoodDeckSF: 0.01095
# FireplaceQu: 0.00978
# GarageType: 0.00910
# HalfBath: 0.00787
# ExterQual: 0.00648
# BsmtExposure: 0.00563
# MasVnrArea: 0.00521
# OpenPorchSF: 0.00509
# Neighborhood: 0.00503
# CentralAir: 0.00397
# RoofStyle: 0.00372
# BsmtQual: 0.00351
# SecondFlrSF: 0.00282
# HeatingQC: 0.00275
# BedroomAbvGr: 0.00266
# MSZoning: 0.00219
# Exterior1st: 0.00213
# MSSubClass: 0.00133
# MasVnrType: 0.00105
# FullBath: 0.00093
# TotRmsAbvGrd: 0.00091
# LandContour: 0.00088
# MoSold: 0.00040
# LandSlope: 0.00038
# KitchenAbvGr: 0.00034
# ExterCond: 0.00017
# Exterior2nd: 0.00012
# GarageCond: 0.00010
# Functional: 0.00010
# ScreenPorch: 0.00010
# RoofMatl: 0.00009
# Electrical: 0.00008
# LotConfig: 0.00008
# OverallCond: 0.00007
# BsmtFullBath: 0.00003
# Condition2: 0.00002
# BsmtHalfBath: 0.00002
# EnclosedPorch: 0.00001
# Heating: 0.00001
# LotFrontage_ISNULL: 0.00001
# GarageYrBlt_ISNULL: 0.00001
# Fence: 0.00000
# BsmtCond: 0.00000
# GarageQual: 0.00000
# ThreeSsnPorch: 0.00000
# Alley: 0.00000
# MiscVal: 0.00000
# MasVnrArea_ISNULL: 0.00000
# MiscFeature: 0.00000
# PoolArea: 0.00000
# PoolQC: 0.00000
# Utilities: 0.00000
# Street: 0.00000
# LowQualFinSF: -0.00000
# PavedDrive: -0.00001
# BldgType: -0.00002
# BsmtFinType2: -0.00002
# YrSold: -0.00005
# BsmtFinSF2: -0.00006
# GarageFinish: -0.00006
# HouseStyle: -0.00013
# Condition1: -0.00016
# SaleType: -0.00024
# SaleCondition: -0.00045
# Foundation: -0.00131
# LotShape: -0.00133
# LotFrontage: -0.00184
# BsmtUnfSF: -0.00251

# %% [markdown]
# <a name="part-two---model-comparison"></a>
# # Part Two - Model Comparison
#
# Early in the modeling process a decision needs to made about which type of model to use. This choice should be driven by the nature of the modeling problem, the nature of the data, and the relationship between the predictors and the target variable. Even after these considerations have been made there are often multiple viable options. This section compares the fit of different models using all of the predictor variables (this can be changed the p_predictors argument). Within the code you can choose the set of hyperparameters you want to test for each model. Soon there will be an additional section here to do a hyperparameter search using some combination of Bayesian Optimization, grid search, and random search.

# %%
#warnings.filterwarnings('ignore')

ModelTools.ModelComparisonRegression(p_X_train = X_train,
                                     p_X_val = X_val,
                                     p_Y_train = Y_train,
                                     p_Y_val = Y_val,
                                     p_predictors = predictors_enc,
                                     p_metric = 'L1')
# Out:
#                            Model  Validation Error
# 9                   SG Boost 100      15661.506292
# 10                 XG Boost 1000      16064.065679
# 6               Random Forest 50      17229.292658
# 7                 Extra Trees 50      18689.356384
# 1           Ridge Regression 1.0      19909.770704
# 3   Elastic Net Regression 0.001      20414.244964
# 2         Lasso Regression 0.001      21305.917454
# 0              Linear Regression      21684.667052
# 8                  Ada Boost 100      25497.799053
# 5                         CART 5      28093.146683
# 4                          KNN 1      33520.632877

# %% [markdown]
# <a name="part-three---variable-selection"></a>
# # Part Three - Variable Selection
#
# Once a model has been chosen, we need to decide which predictor variables to include. Variable selection will be done using backward and forward stepwise selection. The backward part of this algorithm begins by starting with all, say $n$, predictor variables and iteratively removing one variable at a time and measuring the change in performance. The worst performing variable is then removed from the model. We repeat the process with the $n-1$ remaining variables, again removing the worst performing variable. This continues until all of the remaining variables make a "significant" contribution to the model fit. The specific stopping criteria will depend on the problem and metric that is chosen. The forward stepwise selection will then be run (if p_forward = True), by iteratively adding each of the variables that were removed in the backward selection. The most significant, if there any, will be added back to the model. This process continues until none of the remaining variables significantly improve the model.
# <br>
# It may not be immediately clear why the forward iteration is useful. The backward (and forward) stepwise selection is a greedy algorithm and may find a local optimum in the feature space. Running the forward iteration will increase the chance of finding the global optimum, however does not guarantee it. Ideally we would compare the model fit on every subset of our preditor variables, however this is computationally expensive with $O(2^n)$ run-time, compared to $O(n^2)$ run-time with the backward/forward selection.

# %% [markdown]
# <a name="random-forest"></a>
# ## Random Forest
#
# Here we run backward and forward stepwise selection with Random Forest models. Similar to the univariate random forest section we will cross-validate using p_cross_validations splits and p_validation_fraction portion of the data in each test set. And again to reduce run-time, instead of removing variables and re-fitting, we will randomize the variable we would like to remove which should have the same effect.

# %%
ModelTools.ForBackRandomForestPremutations(p_features = features,
                                           p_predictors = predictors_enc,
                                           p_X_train = X_train,
                                           p_Y_train = Y_train,
                                           p_X_val = X_val,
                                           p_Y_val = Y_val,
                                           p_regression = True,
                                           p_metric = 'L1 Error')

# %% [markdown]
# <a name="gradient-boosting"></a>
# ## Gradient Boosting
#
# This section is analagous to the one above, except using gradient boosting.

# %%
ModelTools.ForBackGradientBoostingPremutations(p_features = features,
                                               p_predictors = predictors_enc,
                                               p_X_train = X_train,
                                               p_Y_train = Y_train,
                                               p_X_val = X_val,
                                               p_Y_val = Y_val,
                                               p_regression = True,
                                               p_metric = 'L1 Error')
